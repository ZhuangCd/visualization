# %%
import pandas as pd

df = pd.read_csv("global_leader_ideologies.csv")

df.head()
# Out:
#   country_name  country_code_cow  year                          hog  \
# 0  Afghanistan               700  1945  Sardar Mohammad Hashim Khan
# 1  Afghanistan               700  1946      Sardar Shah Mahmud Khan
# 2  Afghanistan               700  1947      Sardar Shah Mahmud Khan
# 3  Afghanistan               700  1948      Sardar Shah Mahmud Khan
# 4  Afghanistan               700  1949      Sardar Shah Mahmud Khan
#
#      hog_ideology hog_ideology_num_full hog_ideology_num_redux  hog_right  \
# 0  no information        no information       missing ideology        0.0
# 1  no information        no information       missing ideology        0.0
# 2  no information        no information       missing ideology        0.0
# 3  no information        no information       missing ideology        0.0
# 4  no information        no information       missing ideology        0.0
#
#    hog_left  hog_center  ...  match_hog_leader_m  match_leader_leader_m  \
# ...
